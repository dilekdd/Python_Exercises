# %% [markdown]
# <a href="https://www.kaggle.com/code/dilekdd/python-exercises?scriptVersionId=194323158" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Examine the types of data structures

# %%
x = 8
type(x)
# Out:
# int

# %%
y = 3.2
type(y)
# Out:
# float

# %%
z = 8j + 18
type(z)
# Out:
# complex

# %%
a = "Hello World"
type(a)
# Out:
# str

# %%
b = True
type(b)
# Out:
# bool

# %%
c = 23 < 22
type(c)
# Out:
# bool

# %%
l = [1, 2, 3, 4,"String",3.2, False]
type(l)
# Out:
# list

# %%
d = {"Name": "Jake",
     "Age": [27,56],
     "Adress": "Downtown"}
type(d)
# Out:
# dict

# %%
t = ("Machine Learning", "Data Science")
type(t)
# Out:
# tuple

# %%
s = {"Python", "Machine Learning", "Data Science","Python"}
type(s)
# Out:
# set

# %% [markdown]
# Translate the given string to uppercase, replace commas and periods with spaces, and separate the words individually.

# %%
text = "The goal is to turn data into information, and information into insight."
text = text.replace('.', ' ' ).replace(',', ' ')
guncel_text = (', '.join([f'"{word}"' for word in text.split()])).upper()
print(f'[{guncel_text}]')
# Out:
# ["THE", "GOAL", "IS", "TO", "TURN", "DATA", "INTO", "INFORMATION", "AND", "INFORMATION", "INTO", "INSIGHT"]

# %%
text = "The goal is to turn data into information, and information into insight."
text = text.replace('.', ' ' ).replace(',', ' ')
bol_buyut = (word.upper() for word in text.split())
guncel_text = ', '.join([f'"{word}"' for word in bol_buyut])
print(f'[{guncel_text}]')
# Out:
# ["THE", "GOAL", "IS", "TO", "TURN", "DATA", "INTO", "INFORMATION", "AND", "INFORMATION", "INTO", "INSIGHT"]

# %% [markdown]
# Check the number of elements in the given list.

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
len(lst)
# Out:
# 11

# %% [markdown]
# Call the elements at the zeroth and tenth index.

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
[lst[0], lst[10]]
# Out:
# ['D', 'E']

# %% [markdown]
# Create the list of ["D", "A", "T", "A"] from the given list.

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
lst[0:4]
# Out:
# ['D', 'A', 'T', 'A']

# %% [markdown]
# Delete the element at the eighth index

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
lst.pop(8)
print(lst)
# Out:
# ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'C', 'E']

# %% [markdown]
# Add a new element to the list

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
lst.append("T")
print(lst)
# Out:
# ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'N', 'C', 'E', 'T']

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
lst.insert(0, "T")
print(lst)
# Out:
# ['T', 'D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'N', 'C', 'E']

# %% [markdown]
# Re-add the element "N" at the eighth index.

# %%
lst = ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'C', 'E']
lst.insert(8, 'N')
print(lst)
# Out:
# ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'N', 'C', 'E']

# %% [markdown]
# Call the "keys' of the given dictionary

# %%
dict = {'Christian': ["America",18],
        'Daisy':["England",12],
        'Antonio':["Spain",22],
        'Dante':["Italy",25]}
dict.keys()
# Out:
# dict_keys(['Christian', 'Daisy', 'Antonio', 'Dante'])

# %% [markdown]
# Call the 'values' of the given dictionary

# %%
dict = {'Christian': ["America",18],
        'Daisy':["England",12],
        'Antonio':["Spain",22],
        'Dante':["Italy",25]}
dict.values()
# Out:
# dict_values([['America', 18], ['England', 12], ['Spain', 22], ['Italy', 25]])

# %% [markdown]
# Update the value of the Daisy key from 12 to 13

# %%
dict = {'Christian': ["America",18],
        'Daisy':["England",12],
        'Antonio':["Spain",22],
        'Dante':["Italy",25]}

dict['Daisy'] = ["England", 13]
print(dict)
# Out:
# {'Christian': ['America', 18], 'Daisy': ['England', 13], 'Antonio': ['Spain', 22], 'Dante': ['Italy', 25]}

# %% [markdown]
# Add a new entry with the key Ahmet and the value [Turkey, 24]

# %%
dict = {'Christian': ["America",18],
        'Daisy':["England",12],
        'Antonio':["Spain",22],
        'Dante':["Italy",25]}

dict.update({"Ahmet": ("Turkey", 24)})

print(dict)
# Out:
# {'Christian': ['America', 18], 'Daisy': ['England', 12], 'Antonio': ['Spain', 22], 'Dante': ['Italy', 25], 'Ahmet': ('Turkey', 24)}

# %% [markdown]
# Remove Antonio from the given dictionary

# %%
dict = {'Christian': ["America",18],
        'Daisy':["England",12],
        'Antonio':["Spain",22],
        'Dante':["Italy",25]}


dict.pop('Antonio')

print(dict)
# Out:
# {'Christian': ['America', 18], 'Daisy': ['England', 12], 'Dante': ['Italy', 25]}

# %% [markdown]
# Write a function that takes a list as an argument, assigns the odd and even numbers in the list to separate lists, and returns these lists. Multiple ways will be shared. However, Enumarate is prefered one.

# %%
l = [2, 13, 18, 93, 22]
group_l = [[], []]

def tek_cift(l):
    for i, value in enumerate(l):
        if i % 2 == 0:
            group_l[0].append(value)
        else:
            group_l[1].append(value)
    return group_l
tek_cift(l)
# Out:
# [[2, 18, 22], [13, 93]]

# %%
l = [2, 13, 18, 93, 22]

l_tek = []
l_cift = []
for i in range(len(l)):
    if i % 2 == 0:
        l_cift.append(l[i])
    else:
        l_tek.append(l[i])
        
print(l_tek, l_cift)
# Out:
# [13, 93] [2, 18, 22]

# %%
l = [2, 13, 18, 93, 22]

tek_cift = [[], []]
modified_list = [tek_cift[0].append(value) if i % 2 == 0 else tek_cift[1].append(value) for i, value in enumerate(l)]

print(tek_cift)
# Out:
# [[2, 18, 22], [13, 93]]

# %%
l = [2, 13, 18, 93, 22]

tek_cift = [[], []]

modified_list = [tek_cift[0].append(l[i]) if i % 2 == 0 else tek_cift[1].append(l[i]) for i in range(len(l))]

print(tek_cift)
# Out:
# [[2, 18, 22], [13, 93]]

# %% [markdown]
# The list provided below contains the names of students who ranked in the Engineering and Medicine faculties.
#
# The first three students represent the ranking in the engineering, while the last three belong to the medicine.
#
# Use enumerate to print the student rankings specific to each faculty.

# %%
ogrenciler = ["Ali","Veli","Ayşe","Talat","Zeynep","Ece"]

sayac = 1

for i, value in enumerate(ogrenciler, start=1):
    if i <= 3:
        print(f"Muhendislik Fakultesi {i}. Ogrenci, {value}")
    if i > 3:
        print(f"Tip Fakultesi {sayac}. Ogrenci, {value}")
        sayac += 1
# Out:
# Muhendislik Fakultesi 1. Ogrenci, Ali
# Muhendislik Fakultesi 2. Ogrenci, Veli
# Muhendislik Fakultesi 3. Ogrenci, Ayşe
# Tip Fakultesi 1. Ogrenci, Talat
# Tip Fakultesi 2. Ogrenci, Zeynep
# Tip Fakultesi 3. Ogrenci, Ece

# %%
ogrenciler = ["Ali","Veli","Ayşe","Talat","Zeynep","Ece"]

for index, ogrenci in enumerate(ogrenciler, 1):
    if index < 4:
        print("Mühendislik Fakültesi", index, ". ögrenci", ogrenci)
    else:
        print("Tıp Fakültesi", (index-3), ". ögrenci", ogrenci)
# Out:
# Mühendislik Fakültesi 1 . ögrenci Ali
# Mühendislik Fakültesi 2 . ögrenci Veli
# Mühendislik Fakültesi 3 . ögrenci Ayşe
# Tıp Fakültesi 1 . ögrenci Talat
# Tıp Fakültesi 2 . ögrenci Zeynep
# Tıp Fakültesi 3 . ögrenci Ece

# %% [markdown]
# Three lists are provided below.
#
# The lists contain the course code, credits, and capacity information, respectively.
#
# Use zip to print the course details.

# %%
ders_kodu = ["CMP1005","PSY1001","HUK1005","SEN2204"]
kredi = [3,4,2,4]
kontenjan = [30,75,150,25]

ders_bilgileri = zip(ders_kodu, kredi, kontenjan)
for ders, kredi, kontenjan in ders_bilgileri:
    print(f"Kredisi {kredi} olan {ders} kodlu dersin kontenjani {kontenjan} kisidir ")
# Out:
# Kredisi 3 olan CMP1005 kodlu dersin kontenjani 30 kisidir
# Kredisi 4 olan PSY1001 kodlu dersin kontenjani 75 kisidir
# Kredisi 2 olan HUK1005 kodlu dersin kontenjani 150 kisidir
# Kredisi 4 olan SEN2204 kodlu dersin kontenjani 25 kisidir

# %%
ders_kodu = ["CMP1005","PSY1001","HUK1005","SEN2204"]
kredi = [3,4,2,4]
kontenjan = [30,75,150,25]

for i, ders in enumerate(ders_kodu):
    print(f"Kredisi {kredi[i]} olan {ders} kodlu dersin kontenjani {kontenjan[i]} kisidir")
# Out:
# Kredisi 3 olan CMP1005 kodlu dersin kontenjani 30 kisidir
# Kredisi 4 olan PSY1001 kodlu dersin kontenjani 75 kisidir
# Kredisi 2 olan HUK1005 kodlu dersin kontenjani 150 kisidir
# Kredisi 4 olan SEN2204 kodlu dersin kontenjani 25 kisidir

# %% [markdown]
# Two sets are provided below.
#
# You are asked to define a function that prints the common elements if the first set includes the second set, or prints the difference of the second set from the first set if it does not.

# %%
kume1 = set(["data", "python"])
kume2 = set(["data", "function", "qcut", "lambda", "python", "miuul"])

if kume1.issuperset(kume2):
    print(kume1.intersection(kume2))
else:
    print(kume2.difference(kume1))
# Out:
# {'function', 'qcut', 'lambda', 'miuul'}
